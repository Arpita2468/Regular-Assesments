# %%
import pandas as pd

# %%
a=pd.read_csv("D:/PYTHON/0_PROJECT/CSV Files/social media influencers - youtube.csv")
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.head()
# Out:
#   youtuber name                channel name       Category Subscribers  \
# 0       tseries                    T-Series  Music & Dance      212.1M
# 1     checkgate  Cocomelon - Nursery Rhymes      Education      132.1M
# 2      setindia                   SET India            NaN      130.4M
# 3     PewDiePie                   PewDiePie      Animation      111.4M
# 4   MrBeast6000                     MrBeast    Video games       92.5M
#
#   Audience Country avg views avg likes avg comments
# 0            India    323.7K      9.8K          290
# 1              NaN     13.8M     80.9K          NaN
# 2            India     23.6K       314           21
# 3    United States      1.4M     80.8K         4.6K
# 4    United States     30.6M      1.7M        67.7K

# %%
a.tail()
# Out:
#     youtuber name channel name       Category Subscribers Audience Country  \
# 995   FutParódias  FutParódias  Music & Dance        9.2M           Brazil
# 996       EL GATO      EL GATO           Toys        9.2M           Brazil
# 997    CinemaSins   CinemaSins         Movies        9.2M    United States
# 998    CricketICC          ICC         Sports        9.2M            India
# 999       BRKsEDU      BRKsEDU      Animation        9.2M           Brazil
#
#     avg views avg likes avg comments
# 995      1.4M    110.1K         2.5K
# 996    243.8K     30.7K          636
# 997      296K     10.2K          874
# 998     15.2K       854           58
# 999    112.3K      9.8K          246

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   youtuber name     1000 non-null   object
#  1   channel name      1000 non-null   object
#  2   Category          723 non-null    object
#  3   Subscribers       1000 non-null   object
#  4   Audience Country  839 non-null    object
#  5   avg views         1000 non-null   object
#  6   avg likes         962 non-null    object
#  7   avg comments      791 non-null    object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
a.describe()
# Out:
#        youtuber name        channel name       Category Subscribers  \
# count           1000                1000            723        1000
# unique           998                 998             23         228
# top     PrestonPlayz  Bollywood Classics  Music & Dance       10.1M
# freq               2                   2            224          34
#
#        Audience Country avg views avg likes avg comments
# count               839      1000       962          791
# unique               27       743       615          420
# top       United States         0      1.2K         1.8K
# freq                291        18        17           14

# %%
a.shape
# Out:
# (1000, 8)

# %%
a.values
# Out:
# array([['tseries', 'T-Series', 'Music & Dance', ..., '323.7K', '9.8K',
#         '290'],
#        ['checkgate', 'Cocomelon - Nursery Rhymes', 'Education', ...,
#         '13.8M', '80.9K', nan],
#        ['setindia', 'SET India', nan, ..., '23.6K', '314', '21'],
#        ...,
#        ['CinemaSins', 'CinemaSins', 'Movies', ..., '296K', '10.2K',
#         '874'],
#        ['CricketICC', 'ICC', 'Sports', ..., '15.2K', '854', '58'],
#        ['BRKsEDU', 'BRKsEDU', 'Animation', ..., '112.3K', '9.8K', '246']],
#       dtype=object)

# %%
a.columns
# Out:
# Index(['youtuber name', 'channel name', 'Category', 'Subscribers',
#        'Audience Country', 'avg views', 'avg likes', 'avg comments'],
#       dtype='object')

# %%
a.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
a.ind=a.sort_values('avg likes')
a.ind
# Out:
# C:\Users\Arpita Goswami\AppData\Local\Temp\ipykernel_16624\3487271644.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   a.ind=a.sort_values('avg likes')
#            youtuber name         channel name         Category Subscribers  \
# 876  Heroine Movies 2022  Heroine Movies 2022      Daily vlogs        9.9M
# 216   NationalGeographic  National Geographic              NaN       19.8M
# 623   Blockbuster Movies   Blockbuster Movies      Daily vlogs       11.7M
# 766     OYUNCAKOYNUYORUM     OYUNCAKOYNUYORUM              NaN       10.7M
# 779       BuzzFeedYellow                As/Is          Fashion       10.5M
# ..                   ...                  ...              ...         ...
# 879        barcroftmedia                truly  News & Politics        9.8M
# 894    Vlad and Niki PRT    Vlad and Niki PRT              NaN        9.7M
# ...

# %%
a.ind.head()
# Out:
#            youtuber name         channel name     Category Subscribers  \
# 876  Heroine Movies 2022  Heroine Movies 2022  Daily vlogs        9.9M
# 216   NationalGeographic  National Geographic          NaN       19.8M
# 623   Blockbuster Movies   Blockbuster Movies  Daily vlogs       11.7M
# 766     OYUNCAKOYNUYORUM     OYUNCAKOYNUYORUM          NaN       10.7M
# 779       BuzzFeedYellow                As/Is      Fashion       10.5M
#
#     Audience Country avg views avg likes avg comments
# 876            India    151.9K      1.1K           22
# 216    United States     45.8K      1.1K           74
# 623            India    118.5K      1.1K           23
# 766              NaN    311.2K      1.1K          NaN
# 779    United States     27.1K      1.1K           12
